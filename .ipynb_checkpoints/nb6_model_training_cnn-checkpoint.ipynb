# %%
# Retrieve previously stored variables
# %store -r x_train
# %store -r x_test 
# %store -r y_train
# %store -r y_test
# %store -r yy
# %store -r le
# %store -r max_pad_length
print(x_train.shape)
#print(x_train[1345])
# Out:
# (1346, 40, 173)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_rows = 40
num_columns = max_pad_length
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

num_labels = yy.shape[1]

# Construct CNN model
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

# Increasing nodes from 16, 32, 64, 128
model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

# Output based on number of category labels
model.add(Dense(num_labels, activation='softmax'))
# Out:
# Using TensorFlow backend.

# %%
# Compile the model
# Optimizer "adam" is a typical optimizer used - variation SGD (stochastic gradient descent)
# SGD utilizes the gradient of the loss function with respects to the weight
# loss -> typical loss function 
# metrics is output to be displayed (accuracy is the output of the loss function (?))
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
# Verbose - displays info if desired (verbose = 0 means silent, just print accuracy value)
# evaluate returns loss value and score value
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

# Accuracy - the metrics value evaluated based on loss function
print("Pre-training accuracy: %.4f%%" % accuracy)

display(score)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 39, 172, 16)       80
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 20, 64)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 19, 128)        32896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 9, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 9, 128)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 43,828
# Trainable params: 43,828
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 11.3333%
# [5.299432442982991, 0.1133333370089531]

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 8 # Arbitrarily chose the value 8

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)

start = datetime.now()

# Train the model for a fix number of epochs
# validation_data - data to evaluate the loss at the end of each epoch
# callbacks - display ModelCheckpoint
model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 1346 samples, validate on 150 samples
# Epoch 1/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 1.5699 - accuracy: 0.5646 - val_loss: 0.6582 - val_accuracy: 0.7600
#
# Epoch 00001: val_loss improved from inf to 0.65823, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 1346/1346 [==============================] - 9s 6ms/step - loss: 0.6168 - accuracy: 0.7623 - val_loss: 0.5212 - val_accuracy: 0.8333
#
# Epoch 00002: val_loss improved from 0.65823 to 0.52123, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 3/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.4704 - accuracy: 0.8254 - val_loss: 0.4424 - val_accuracy: 0.8533
#
# Epoch 00003: val_loss improved from 0.52123 to 0.44242, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 4/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.4140 - accuracy: 0.8455 - val_loss: 0.5722 - val_accuracy: 0.7867
#
# Epoch 00004: val_loss did not improve from 0.44242
# Epoch 5/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.3287 - accuracy: 0.8826 - val_loss: 0.3527 - val_accuracy: 0.8667
#
# Epoch 00005: val_loss improved from 0.44242 to 0.35273, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 6/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.3518 - accuracy: 0.8670 - val_loss: 0.3619 - val_accuracy: 0.8733
#
# Epoch 00006: val_loss did not improve from 0.35273
# Epoch 7/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.2852 - accuracy: 0.8938 - val_loss: 0.3009 - val_accuracy: 0.9000
#
# Epoch 00007: val_loss improved from 0.35273 to 0.30093, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 8/100
# 1346/1346 [==============================] - 9s 7ms/step - loss: 0.2634 - accuracy: 0.8990 - val_loss: 0.3187 - val_accuracy: 0.9000
#
# Epoch 00008: val_loss did not improve from 0.30093
# Epoch 9/100
# 1346/1346 [==============================] - 9s 7ms/step - loss: 0.2567 - accuracy: 0.9086 - val_loss: 0.3028 - val_accuracy: 0.8933
#
# Epoch 00009: val_loss did not improve from 0.30093
# Epoch 10/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.2709 - accuracy: 0.8997 - val_loss: 0.3524 - val_accuracy: 0.8867
#
# Epoch 00010: val_loss did not improve from 0.30093
# Epoch 11/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.2144 - accuracy: 0.9250 - val_loss: 0.3690 - val_accuracy: 0.8800
#
# Epoch 00011: val_loss did not improve from 0.30093
# Epoch 12/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.2202 - accuracy: 0.9235 - val_loss: 0.3718 - val_accuracy: 0.8867
#
# Epoch 00012: val_loss did not improve from 0.30093
# Epoch 13/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1858 - accuracy: 0.9354 - val_loss: 0.3872 - val_accuracy: 0.8733
#
# Epoch 00013: val_loss did not improve from 0.30093
# Epoch 14/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1640 - accuracy: 0.9398 - val_loss: 0.4406 - val_accuracy: 0.8933
#
# Epoch 00014: val_loss did not improve from 0.30093
# Epoch 15/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1835 - accuracy: 0.9309 - val_loss: 0.3355 - val_accuracy: 0.8867
#
# Epoch 00015: val_loss did not improve from 0.30093
# Epoch 16/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.2207 - accuracy: 0.9272 - val_loss: 0.3006 - val_accuracy: 0.9000
#
# Epoch 00016: val_loss improved from 0.30093 to 0.30061, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 17/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1726 - accuracy: 0.9331 - val_loss: 0.2877 - val_accuracy: 0.9200
#
# Epoch 00017: val_loss improved from 0.30061 to 0.28768, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 18/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1415 - accuracy: 0.9480 - val_loss: 0.2575 - val_accuracy: 0.9133
#
# Epoch 00018: val_loss improved from 0.28768 to 0.25748, saving model to saved_models/weights.best.basic_mlp.hdf5
# Epoch 19/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.1328 - accuracy: 0.9547 - val_loss: 0.2751 - val_accuracy: 0.9200
#
# Epoch 00019: val_loss did not improve from 0.25748
# Epoch 20/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.1267 - accuracy: 0.9539 - val_loss: 0.4075 - val_accuracy: 0.8867
#
# Epoch 00020: val_loss did not improve from 0.25748
# Epoch 21/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1314 - accuracy: 0.9539 - val_loss: 0.4597 - val_accuracy: 0.9000
#
# Epoch 00021: val_loss did not improve from 0.25748
# Epoch 22/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.1326 - accuracy: 0.9539 - val_loss: 0.3079 - val_accuracy: 0.9133
#
# Epoch 00022: val_loss did not improve from 0.25748
# Epoch 23/100
# 1346/1346 [==============================] - 9s 7ms/step - loss: 0.1108 - accuracy: 0.9643 - val_loss: 0.3181 - val_accuracy: 0.8933
#
# Epoch 00023: val_loss did not improve from 0.25748
# Epoch 24/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.1310 - accuracy: 0.9539 - val_loss: 0.3968 - val_accuracy: 0.8800
#
# Epoch 00024: val_loss did not improve from 0.25748
# Epoch 25/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1106 - accuracy: 0.9562 - val_loss: 0.6481 - val_accuracy: 0.8467
#
# Epoch 00025: val_loss did not improve from 0.25748
# Epoch 26/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1533 - accuracy: 0.9473 - val_loss: 0.2879 - val_accuracy: 0.9133
#
# Epoch 00026: val_loss did not improve from 0.25748
# Epoch 27/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0890 - accuracy: 0.9681 - val_loss: 0.2634 - val_accuracy: 0.9333
#
# Epoch 00027: val_loss did not improve from 0.25748
# Epoch 28/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1180 - accuracy: 0.9606 - val_loss: 0.2755 - val_accuracy: 0.9067
#
# Epoch 00028: val_loss did not improve from 0.25748
# Epoch 29/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0968 - accuracy: 0.9725 - val_loss: 0.3724 - val_accuracy: 0.8933
#
# Epoch 00029: val_loss did not improve from 0.25748
# Epoch 30/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1081 - accuracy: 0.9621 - val_loss: 0.4799 - val_accuracy: 0.8733
#
# Epoch 00030: val_loss did not improve from 0.25748
# Epoch 31/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0842 - accuracy: 0.9673 - val_loss: 0.3356 - val_accuracy: 0.8933
#
# Epoch 00031: val_loss did not improve from 0.25748
# Epoch 32/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0535 - accuracy: 0.9814 - val_loss: 0.3327 - val_accuracy: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.25748
# Epoch 33/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0835 - accuracy: 0.9710 - val_loss: 0.2858 - val_accuracy: 0.9133
#
# Epoch 00033: val_loss did not improve from 0.25748
# Epoch 34/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0925 - accuracy: 0.9725 - val_loss: 0.2945 - val_accuracy: 0.9400
#
# Epoch 00034: val_loss did not improve from 0.25748
# Epoch 35/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0711 - accuracy: 0.9762 - val_loss: 0.3131 - val_accuracy: 0.9467
#
# Epoch 00035: val_loss did not improve from 0.25748
# Epoch 36/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0870 - accuracy: 0.9725 - val_loss: 0.2689 - val_accuracy: 0.9467
#
# Epoch 00036: val_loss did not improve from 0.25748
# Epoch 37/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0724 - accuracy: 0.9740 - val_loss: 0.2681 - val_accuracy: 0.9400
#
# Epoch 00037: val_loss did not improve from 0.25748
# Epoch 38/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0857 - accuracy: 0.9703 - val_loss: 0.5258 - val_accuracy: 0.8933
#
# Epoch 00038: val_loss did not improve from 0.25748
# Epoch 39/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1437 - accuracy: 0.9606 - val_loss: 0.3288 - val_accuracy: 0.9133
#
# Epoch 00039: val_loss did not improve from 0.25748
# Epoch 40/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0657 - accuracy: 0.9814 - val_loss: 0.3098 - val_accuracy: 0.9267
#
# Epoch 00040: val_loss did not improve from 0.25748
# Epoch 41/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0664 - accuracy: 0.9851 - val_loss: 0.2860 - val_accuracy: 0.9400
#
# Epoch 00041: val_loss did not improve from 0.25748
# Epoch 42/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0384 - accuracy: 0.9889 - val_loss: 0.3247 - val_accuracy: 0.9400
#
# Epoch 00042: val_loss did not improve from 0.25748
# Epoch 43/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0609 - accuracy: 0.9799 - val_loss: 0.4340 - val_accuracy: 0.9200
#
# Epoch 00043: val_loss did not improve from 0.25748
# Epoch 44/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0862 - accuracy: 0.9725 - val_loss: 0.4902 - val_accuracy: 0.9000
#
# Epoch 00044: val_loss did not improve from 0.25748
# Epoch 45/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0615 - accuracy: 0.9770 - val_loss: 0.2885 - val_accuracy: 0.9267
#
# Epoch 00045: val_loss did not improve from 0.25748
# Epoch 46/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0584 - accuracy: 0.9785 - val_loss: 0.3452 - val_accuracy: 0.9200
#
# Epoch 00046: val_loss did not improve from 0.25748
# Epoch 47/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0318 - accuracy: 0.9933 - val_loss: 0.3109 - val_accuracy: 0.9467
#
# Epoch 00047: val_loss did not improve from 0.25748
# Epoch 48/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0331 - accuracy: 0.9851 - val_loss: 0.3552 - val_accuracy: 0.9267
#
# Epoch 00048: val_loss did not improve from 0.25748
# Epoch 49/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0602 - accuracy: 0.9807 - val_loss: 0.3553 - val_accuracy: 0.9200
#
# Epoch 00049: val_loss did not improve from 0.25748
# Epoch 50/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1269 - accuracy: 0.9584 - val_loss: 0.4316 - val_accuracy: 0.8867
#
# Epoch 00050: val_loss did not improve from 0.25748
# Epoch 51/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0400 - accuracy: 0.9844 - val_loss: 0.3259 - val_accuracy: 0.9400
#
# Epoch 00051: val_loss did not improve from 0.25748
# Epoch 52/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0277 - accuracy: 0.9933 - val_loss: 0.3875 - val_accuracy: 0.9467
#
# Epoch 00052: val_loss did not improve from 0.25748
# Epoch 53/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0838 - accuracy: 0.9807 - val_loss: 0.5313 - val_accuracy: 0.9000
#
# Epoch 00053: val_loss did not improve from 0.25748
# Epoch 54/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0476 - accuracy: 0.9814 - val_loss: 0.3613 - val_accuracy: 0.9200
#
# Epoch 00054: val_loss did not improve from 0.25748
# Epoch 55/100
# 1346/1346 [==============================] - 8s 6ms/step - loss: 0.0281 - accuracy: 0.9903 - val_loss: 0.3428 - val_accuracy: 0.9533
#
# Epoch 00055: val_loss did not improve from 0.25748
# Epoch 56/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0284 - accuracy: 0.9926 - val_loss: 0.4102 - val_accuracy: 0.9267
#
# Epoch 00056: val_loss did not improve from 0.25748
# Epoch 57/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.1062 - accuracy: 0.9703 - val_loss: 0.3204 - val_accuracy: 0.9333
#
# Epoch 00057: val_loss did not improve from 0.25748
# Epoch 58/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0465 - accuracy: 0.9859 - val_loss: 0.3679 - val_accuracy: 0.9467
#
# Epoch 00058: val_loss did not improve from 0.25748
# Epoch 59/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0638 - accuracy: 0.9844 - val_loss: 0.3744 - val_accuracy: 0.9000
#
# Epoch 00059: val_loss did not improve from 0.25748
# Epoch 60/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0394 - accuracy: 0.9881 - val_loss: 0.3813 - val_accuracy: 0.9200
#
# Epoch 00060: val_loss did not improve from 0.25748
# Epoch 61/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0378 - accuracy: 0.9866 - val_loss: 0.2980 - val_accuracy: 0.9333
#
# Epoch 00061: val_loss did not improve from 0.25748
# Epoch 62/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0197 - accuracy: 0.9926 - val_loss: 0.3953 - val_accuracy: 0.9267
#
# Epoch 00062: val_loss did not improve from 0.25748
# Epoch 63/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.3258 - val_accuracy: 0.9267
#
# Epoch 00063: val_loss did not improve from 0.25748
# Epoch 64/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0698 - accuracy: 0.9822 - val_loss: 0.4059 - val_accuracy: 0.9333
#
# Epoch 00064: val_loss did not improve from 0.25748
# Epoch 65/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.3736 - val_accuracy: 0.9467
#
# Epoch 00065: val_loss did not improve from 0.25748
# Epoch 66/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1357 - accuracy: 0.9703 - val_loss: 0.8725 - val_accuracy: 0.8600
#
# Epoch 00066: val_loss did not improve from 0.25748
# Epoch 67/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1670 - accuracy: 0.9591 - val_loss: 0.3400 - val_accuracy: 0.9267
#
# Epoch 00067: val_loss did not improve from 0.25748
# Epoch 68/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0400 - accuracy: 0.9851 - val_loss: 0.3066 - val_accuracy: 0.9333
#
# Epoch 00068: val_loss did not improve from 0.25748
# Epoch 69/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0542 - accuracy: 0.9807 - val_loss: 0.3066 - val_accuracy: 0.9400
#
# Epoch 00069: val_loss did not improve from 0.25748
# Epoch 70/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0418 - accuracy: 0.9903 - val_loss: 0.3247 - val_accuracy: 0.9533
#
# Epoch 00070: val_loss did not improve from 0.25748
# Epoch 71/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0274 - accuracy: 0.9911 - val_loss: 0.2611 - val_accuracy: 0.9533
#
# Epoch 00071: val_loss did not improve from 0.25748
# Epoch 72/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0484 - accuracy: 0.9859 - val_loss: 0.4737 - val_accuracy: 0.9067
#
# Epoch 00072: val_loss did not improve from 0.25748
# Epoch 73/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.3106 - val_accuracy: 0.9333
#
# Epoch 00073: val_loss did not improve from 0.25748
# Epoch 74/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0317 - accuracy: 0.9889 - val_loss: 0.3261 - val_accuracy: 0.9333
#
# Epoch 00074: val_loss did not improve from 0.25748
# Epoch 75/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0615 - accuracy: 0.9866 - val_loss: 0.2912 - val_accuracy: 0.9400
#
# Epoch 00075: val_loss did not improve from 0.25748
# Epoch 76/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0707 - accuracy: 0.9792 - val_loss: 0.2886 - val_accuracy: 0.9467
#
# Epoch 00076: val_loss did not improve from 0.25748
# Epoch 77/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0431 - accuracy: 0.9859 - val_loss: 0.3363 - val_accuracy: 0.9533
#
# Epoch 00077: val_loss did not improve from 0.25748
# Epoch 78/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0319 - accuracy: 0.9889 - val_loss: 0.4261 - val_accuracy: 0.9133
#
# Epoch 00078: val_loss did not improve from 0.25748
# Epoch 79/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0222 - accuracy: 0.9903 - val_loss: 0.3449 - val_accuracy: 0.9267
#
# Epoch 00079: val_loss did not improve from 0.25748
# Epoch 80/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0204 - accuracy: 0.9955 - val_loss: 0.3783 - val_accuracy: 0.9467
#
# Epoch 00080: val_loss did not improve from 0.25748
# Epoch 81/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0256 - accuracy: 0.9933 - val_loss: 0.3461 - val_accuracy: 0.9533
#
# Epoch 00081: val_loss did not improve from 0.25748
# Epoch 82/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0263 - accuracy: 0.9903 - val_loss: 0.4364 - val_accuracy: 0.9267
#
# Epoch 00082: val_loss did not improve from 0.25748
# Epoch 83/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0528 - accuracy: 0.9874 - val_loss: 0.4070 - val_accuracy: 0.9200
#
# Epoch 00083: val_loss did not improve from 0.25748
# Epoch 84/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0309 - accuracy: 0.9881 - val_loss: 0.4312 - val_accuracy: 0.9467
#
# Epoch 00084: val_loss did not improve from 0.25748
# Epoch 85/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.4564 - val_accuracy: 0.9400
#
# Epoch 00085: val_loss did not improve from 0.25748
# Epoch 86/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0233 - accuracy: 0.9918 - val_loss: 0.4501 - val_accuracy: 0.9200
#
# Epoch 00086: val_loss did not improve from 0.25748
# Epoch 87/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0114 - accuracy: 0.9948 - val_loss: 0.4950 - val_accuracy: 0.9133
#
# Epoch 00087: val_loss did not improve from 0.25748
# Epoch 88/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.6836 - val_accuracy: 0.8867
#
# Epoch 00088: val_loss did not improve from 0.25748
# Epoch 89/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0722 - accuracy: 0.9829 - val_loss: 0.3994 - val_accuracy: 0.9333
#
# Epoch 00089: val_loss did not improve from 0.25748
# Epoch 90/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.1335 - accuracy: 0.9688 - val_loss: 0.4520 - val_accuracy: 0.9200
#
# Epoch 00090: val_loss did not improve from 0.25748
# Epoch 91/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0700 - accuracy: 0.9755 - val_loss: 0.3379 - val_accuracy: 0.9400
#
# Epoch 00091: val_loss did not improve from 0.25748
# Epoch 92/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0491 - accuracy: 0.9911 - val_loss: 0.4792 - val_accuracy: 0.9133
#
# Epoch 00092: val_loss did not improve from 0.25748
# Epoch 93/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.5552 - val_accuracy: 0.9133
#
# Epoch 00093: val_loss did not improve from 0.25748
# Epoch 94/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0242 - accuracy: 0.9903 - val_loss: 0.3590 - val_accuracy: 0.9267
#
# Epoch 00094: val_loss did not improve from 0.25748
# Epoch 95/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.4195 - val_accuracy: 0.9133
#
# Epoch 00095: val_loss did not improve from 0.25748
# Epoch 96/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.5621 - val_accuracy: 0.9200
#
# Epoch 00096: val_loss did not improve from 0.25748
# Epoch 97/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0569 - accuracy: 0.9851 - val_loss: 0.5079 - val_accuracy: 0.9267
#
# Epoch 00097: val_loss did not improve from 0.25748
# Epoch 98/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0380 - accuracy: 0.9874 - val_loss: 0.4352 - val_accuracy: 0.9200
#
# Epoch 00098: val_loss did not improve from 0.25748
# Epoch 99/100
# 1346/1346 [==============================] - 6s 5ms/step - loss: 0.0163 - accuracy: 0.9933 - val_loss: 0.3990 - val_accuracy: 0.9267
#
# Epoch 00099: val_loss did not improve from 0.25748
# Epoch 100/100
# 1346/1346 [==============================] - 7s 5ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.3706 - val_accuracy: 0.9467
#
# Epoch 00100: val_loss did not improve from 0.25748
# Training completed in time:  0:11:22.279216

# %%
# Test the Model

# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1]*100, "%")

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1]*100, "%")
# Out:
# Training Accuracy:  100.0 %
# Testing Accuracy:  94.66666579246521 %

# %%
# Test MFCC values of Longer Vs. Shorter Samples
# Creating a function that extracts the MFCC features of an audio file
def extract_features(file_name, max_pad_len):
    
    try:
        
        # Librosa extraction of audio array and sampling rate
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') # resampling at a "faster rate as opposed to higher quality"
        # MFCC feature extraction of audio - mfccs is mfcc sequence (array), n_mfcc is number of MFCCs to return
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        # If the number of frames is less than the max_pad_len, zero-pad up to max_pad_len
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')

    except Exception as e:
        print("Error encountered while parsing file ", file_name)
        return None
    
    return mfccs

# %%
def print_prediction(file_name, max_pad_length):
    prediction_feature = extract_features(file_name, max_pad_length)
    #print(prediction_feature)
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
# Validation 
import os
import librosa

# Random dog bark file
cwd = os.getcwd()
filename = cwd + '//UrbanSound8K//audio//fold1//101415-3-0-2.wav'
print_prediction(filename, max_pad_length)

# Siren file
cwd = os.getcwd()
filename = cwd + '//UrbanSound8K//audio//fold3//184623-8-0-1.wav'
print_prediction(filename, max_pad_length)
# Out:
# The predicted class is: dog_bark
#
# car_horn 		 :  0.00000000000000000000000000000000
# dog_bark 		 :  1.00000000000000000000000000000000
# gun_shot 		 :  0.00000000000000000000000000000000
# siren 		 :  0.00000000000000000000000000000000
# The predicted class is: siren
#
# car_horn 		 :  0.00000000000000000000000000000000
# dog_bark 		 :  0.00000000000000000314474051121837
# gun_shot 		 :  0.00000000000000000000000000000000
# siren 		 :  1.00000000000000000000000000000000
